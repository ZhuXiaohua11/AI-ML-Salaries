# %% [markdown]
# import csv

# %%
import pandas as pd
salaries_en_df= pd.read_csv("salaries_encoded.csv")
salaries_en_df.head()
# Out:
#    work_year           job_title  salary_in_usd employee_residence  \
# 0       2025  Data Product Owner         170000                 US
# 1       2025  Data Product Owner         110000                 US
# 2       2025            Engineer         143000                 US
# 3       2025            Engineer         106000                 US
# 4       2025             Manager         360200                 US
#
#    remote_ratio company_location  experience_level_EN  experience_level_EX  \
# 0             0               US                    0                    0
# 1             0               US                    0                    0
# 2             0               US                    0                    0
# 3             0               US                    0                    0
# 4             0               US                    0                    0
#
#    experience_level_MI  experience_level_SE  ...  \
# 0                    0                    1  ...
# ...

# %% [markdown]
# Beskrivande statistik

# %%
salaries_en_df.describe()
# Out:
#           work_year  salary_in_usd  remote_ratio  experience_level_EN  \
# count  34024.000000   34024.000000  34024.000000         34024.000000
# mean    2023.785622  150792.951152     25.944921             0.116271
# std        0.567422   75839.357228     43.599413             0.320554
# min     2020.000000   15000.000000      0.000000             0.000000
# 25%     2024.000000   96153.000000      0.000000             0.000000
# 50%     2024.000000  139400.000000      0.000000             0.000000
# 75%     2024.000000  190200.000000    100.000000             0.000000
# max     2025.000000  800000.000000    100.000000             1.000000
#
#        experience_level_EX  experience_level_MI  experience_level_SE  \
# count         34024.000000         34024.000000         34024.000000
# mean              0.031096             0.321420             0.531213
# std               0.173579             0.467029             0.499032
# ...

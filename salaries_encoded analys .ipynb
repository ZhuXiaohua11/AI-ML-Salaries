# %% [markdown]
# import csv

# %%
import pandas as pd
salaries_en_df= pd.read_csv("salaries_encoded.csv")
salaries_en_df.head()
# Out:
#    work_year           job_title  salary salary_currency  salary_in_usd  \
# 0       2025  Data Product Owner  170000             USD         170000
# 1       2025  Data Product Owner  110000             USD         110000
# 2       2025            Engineer  143000             USD         143000
# 3       2025            Engineer  106000             USD         106000
# 4       2025             Manager  360200             USD         360200
#
#   employee_residence  remote_ratio company_location  experience_level_EN  \
# 0                 US             0               US                    0
# 1                 US             0               US                    0
# 2                 US             0               US                    0
# 3                 US             0               US                    0
# 4                 US             0               US                    0
#
#    experience_level_EX  ...  job_title_simplified_Analytics Engineer  \
# ...
